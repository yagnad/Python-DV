# %% [markdown]
# # 2. Reading a excel file to dataframe

# %%
import pandas as pd
df = pd.read_excel("AGE01.xls")

# %%
df.head()
# Out:
#         Areaname  STCOU  AGE010180F  AGE010180D  AGE010180N1  AGE010180N2  \
# 0  UNITED STATES      0           0   226545805            0            0
# 1        ALABAMA   1000           0     3893888            0            0
# 2    Autauga, AL   1001           0       32259            0            0
# 3    Baldwin, AL   1003           0       78556            0            0
# 4    Barbour, AL   1005           0       24756            0            0
#
#    AGE010190F  AGE010190D  AGE010190N1  AGE010190N2  ...  AGE040202N1  \
# 0           0   248709873            0            0  ...            0
# 1           0     4040587            0            0  ...            0
# 2           0       34222            0            0  ...            0
# 3           0       98280            0            0  ...            0
# 4           0       25417            0            0  ...            0
#
#    AGE040202N2  AGE040203F  AGE040203D  AGE040203N1  AGE040203N2  AGE040204F  \
# ...
